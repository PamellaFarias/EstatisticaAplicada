# %% [markdown]
# <center> <h4>Estatística Aplicada a Computação</h4> </center>

# %% [markdown]
# <center> <h4>Professor: Paulo Ribeiro Lins Junior</h4> </center>

# %% [markdown]
# <center> <h4>Aluna: Pâmella Vitória Gomes Farias</h4> </center>

# %% [markdown]
# <center> <h4>Matrícula: 202021250032</h4> </center>

# %% [markdown]
# <center> <h1>PROJETO 1 </h1> </center>

# %% [markdown]
# <center> <h4>1ª Tarefa</h4> </center>

# %% [markdown]
# 1º PASSO: Importação das bibliotecas que serão necessárias para realizar a resolução dos problemas.

# %%
import numpy as np

# %%
import pandas as pd

# %% [markdown]
# 2º PASSO: Carregamento dos conjuntos de dados referentes aos anos de 2018, 2019 e 2020 considerando que os arquivos estão compactados.

# %%
dtran2018 = pd.read_csv('https://arquivos.prf.gov.br/arquivos/index.php/s/MaC6cieXSFACNWT/download', compression = 'zip')
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-7-c19537dcd8f4> in <module>
# ----> 1 dtran2018 = pd.read_csv('https://arquivos.prf.gov.br/arquivos/index.php/s/MaC6cieXSFACNWT/download', compression = 'zip')
#
# ...

# %% [markdown]
# 3º PASSO: Com o intuito de corrigir o erro encontrado, irei declarar a codificação dos fontes a partir do encoding.

# %%
dtran2018 = pd.read_csv('https://arquivos.prf.gov.br/arquivos/index.php/s/MaC6cieXSFACNWT/download', compression= 'zip', encoding='iso-8859-1')

# %%
dtran2018
# Out:
#                                                                                                                                             id;"data_inversa";"dia_semana";"horario";"uf";"br";"km";"municipio";"causa_acidente";"tipo_acidente";"classificacao_acidente";"fase_dia";"sentido_via";"condicao_metereologica";"tipo_pista";"tracado_via";"uso_solo";"pessoas";"mortos";"feridos_leves";"feridos_graves";"ilesos";"ignorados";"feridos";"veiculos";"latitude";"longitude";"regional";"delegacia";"uop"
# 99973;2018-01-01;"segunda-feira";"00:20:00";"RJ... 5;"RESENDE";"Condutor Dormindo";"Saída de leito... 46937;-44                                              44705;"SR-RJ";"DEL5/7";"UOP03/RJ"
# 99976;2018-01-01;"segunda-feira";"00:40:00";"SC... 4;"FLORIANOPOLIS";"Não guardar distância de seg... 59971687;-48                                        57565694;"SR-SC";"DEL8/1";"UOP01/SC"
# ...

# %% [markdown]
# 4º PASSO: Como observado vai ser necessário utilizar o separador de dados para separar as colunas do Dataframe.

# %%
dtran2018 = pd.read_csv('https://arquivos.prf.gov.br/arquivos/index.php/s/MaC6cieXSFACNWT/download', compression= 'zip', encoding='iso-8859-1', sep=';')

# %%
dtran2018
# Out:
#              id data_inversa     dia_semana   horario  uf     br     km  \
# 0       99973.0   2018-01-01  segunda-feira  00:20:00  RJ  116.0  303,5
# 1       99976.0   2018-01-01  segunda-feira  00:40:00  SC  282.0    0,4
# 2       99977.0   2018-01-01  segunda-feira  00:30:00  RJ  493.0      1
# 3       99981.0   2018-01-01  segunda-feira  01:15:00  RS  386.0    134
# 4       99982.0   2018-01-01  segunda-feira  00:20:00  RS  293.0  151,7
# ...         ...          ...            ...       ...  ..    ...    ...
# 69290  252256.0   2018-12-24  segunda-feira  09:15:00  PI  343.0  263,1
# 69291  252652.0   2018-12-12   quarta-feira  07:00:00  BA  101.0    321
# 69292  252801.0   2018-11-15   quinta-feira  10:48:00  SP  116.0    529
# 69293  253040.0   2018-11-23    sexta-feira  19:30:00  RS  472.0  573,5
# 69294  253078.0   2018-10-01  segunda-feira  04:31:00  GO   40.0      9
#
#                        municipio  \
# 0                        RESENDE
# ...

# %% [markdown]
# 5º PASSO: A mesma codificação e separador de colunas será utilizada na importação dos Dataframes referente aos anos seguintes.

# %%
dtran2019 = pd.read_csv('https://arquivos.prf.gov.br/arquivos/index.php/s/kRBUylqz6DyQznN/download', compression= 'zip', encoding='iso-8859-1', sep=';')

# %%
dtran2019
# Out:
#              id data_inversa     dia_semana   horario  uf     br     km  \
# 0      182210.0   2019-01-01    terça-feira  01:30:00  SP  116.0    218
# 1      182211.0   2019-01-01    terça-feira  01:30:00  PR  373.0  177,3
# 2      182212.0   2019-01-01    terça-feira  00:45:00  SC  101.0     16
# 3      182214.0   2019-01-01    terça-feira  00:00:00  CE   20.0  429,5
# 4      182215.0   2019-01-01    terça-feira  01:00:00  MG  381.0    327
# ...         ...          ...            ...       ...  ..    ...    ...
# 67441  266255.0   2019-10-07  segunda-feira  09:10:00  ES  101.0  270,5
# 67442  266406.0   2019-11-25  segunda-feira  07:20:00  PR  116.0    125
# 67443  266434.0   2019-06-03  segunda-feira  19:00:00  CE  222.0    1,4
# 67444  266573.0   2019-07-13         sábado  19:35:00  PR  373.0    425
# 67445  266627.0   2019-10-22    terça-feira  20:20:00  BA  324.0    608
#
#                 municipio                       causa_acidente  \
# ...

# %%
dtran2020 = pd.read_csv('https://arquivos.prf.gov.br/arquivos/index.php/s/jdDLrQIf33xXSCe/download', compression= 'zip', encoding='iso-8859-1', sep=';')

# %%
dtran2020
# Out:
#              id data_inversa    dia_semana   horario  uf     br     km  \
# 0      260031.0   2020-01-01  quarta-feira  01:00:00  TO  153.0  678,1
# 1      260036.0   2020-01-01  quarta-feira  01:00:00  RJ  116.0    178
# 2      260037.0   2020-01-01  quarta-feira  01:52:00  SC  101.0  206,9
# 3      260038.0   2020-01-01  quarta-feira  01:15:00  RO  364.0    236
# 4      260039.0   2020-01-01  quarta-feira  01:30:00  PR  153.0    360
# ...         ...          ...           ...       ...  ..    ...    ...
# 63543  364615.0   2020-03-20   sexta-feira  09:00:00  RN  304.0  171,8
# 63544  364810.0   2020-09-12        sábado  23:50:00  BA  116.0   11,5
# 63545  364817.0   2020-10-30   sexta-feira  10:30:00  BA  116.0   14,3
# 63546  364835.0   2020-09-20       domingo  23:00:00  BA  116.0      8
# 63547  364903.0   2020-10-31        sábado  02:10:00  BA  116.0      3
#
#                   municipio                causa_acidente  \
# ...

# %% [markdown]
# Foi possível importar diretamente mesmo o arquivo estando compactado, foi necessário apenas considerar o formato do arquivo.

# %% [markdown]
# <center> <h4>2ª Tarefa</h4> </center>

# %% [markdown]
# <center> <h4>Quantidade de acidentes em cada ano</h4> </center>

# %% [markdown]
# 1º PASSO: Para determinar a quantidade de acidentes em cada Dataframe referente a cada ano irei utilizar um comando para fazer a  contagem da quantidade de linhas que há em cada Dataframe.

# %%
dtran2018.count()
# Out:
# id                        69295
# data_inversa              69295
# dia_semana                69295
# horario                   69295
# uf                        69295
# br                        69181
# km                        69181
# municipio                 69295
# causa_acidente            69295
# tipo_acidente             69295
# classificacao_acidente    69295
# fase_dia                  69295
# sentido_via               69295
# condicao_metereologica    69295
# tipo_pista                69295
# tracado_via               69295
# uso_solo                  69295
# pessoas                   69295
# mortos                    69295
# feridos_leves             69295
# feridos_graves            69295
# ilesos                    69295
# ignorados                 69295
# feridos                   69295
# veiculos                  69295
# latitude                  69295
# longitude                 69295
# regional                  69295
# delegacia                 69295
# ...

# %% [markdown]
# Ocorreram 69295 acidentes no ano de 2018.

# %%
dtran2019.count()
# Out:
# id                        67446
# data_inversa              67446
# dia_semana                67446
# horario                   67446
# uf                        67446
# br                        67351
# km                        67351
# municipio                 67446
# causa_acidente            67446
# tipo_acidente             67446
# classificacao_acidente    67446
# fase_dia                  67446
# sentido_via               67446
# condicao_metereologica    67446
# tipo_pista                67446
# tracado_via               67446
# uso_solo                  67446
# pessoas                   67446
# mortos                    67446
# feridos_leves             67446
# feridos_graves            67446
# ilesos                    67446
# ignorados                 67446
# feridos                   67446
# veiculos                  67446
# latitude                  67446
# longitude                 67446
# regional                  67446
# delegacia                 67446
# ...

# %% [markdown]
# Ocorreram 67446 acidentes no ano de 2019.

# %%
dtran2020.count()
# Out:
# id                        63548
# data_inversa              63548
# dia_semana                63548
# horario                   63548
# uf                        63548
# br                        63390
# km                        63390
# municipio                 63548
# causa_acidente            63548
# tipo_acidente             63548
# classificacao_acidente    63548
# fase_dia                  63548
# sentido_via               63548
# condicao_metereologica    63548
# tipo_pista                63548
# tracado_via               63548
# uso_solo                  63548
# pessoas                   63548
# mortos                    63548
# feridos_leves             63548
# feridos_graves            63548
# ilesos                    63548
# ignorados                 63548
# feridos                   63548
# veiculos                  63548
# latitude                  63548
# longitude                 63548
# regional                  63548
# delegacia                 63548
# ...

# %% [markdown]
# Ocorreram 63548 acidentes no ano de 2020.

# %% [markdown]
# <center> <h4>Quantidade de variáveis registrada por cada conjunto de dados</h4> </center>

# %% [markdown]
# 1º PASSO: Como o número de variáveis de cada conjunto de dados corresponde ao número de colunas que cada Dataframe correspondente a cada ano contém, irei fazer a contagem da quantidade de colunas em cada Dataframe referente a cada ano.

# %%
dtran2018.shape[1]
# Out:
# 30

# %% [markdown]
# O conjunto de dados referente ao ano de 2018 possui 30 variáveis.

# %%
dtran2019.shape[1]
# Out:
# 30

# %% [markdown]
# O conjunto de dados referente ao ano de 2019 possui 30 variáveis.

# %%
dtran2020.shape[1]
# Out:
# 30

# %% [markdown]
# O conjunto de dados referente ao ano de 2020 possui 30 variáveis.

# %% [markdown]
# <center> <h4>Cinco cidades brasileiras em que mais ocorreram acidentes em rodovias federais</h4> </center>

# %% [markdown]
# 1º PASSO: Verificar nas colunas quais as frequências de acidentes nos municípios em cada Dataframe referente a cada ano.

# %%
dtran2018["municipio"].value_counts()
# Out:
# CURITIBA         1019
# SAO JOSE          874
# BRASILIA          867
# GUARULHOS         755
# PALHOCA           688
#                  ...
# MILHA               1
# IELMO MARINHO       1
# FIGUEIRAO           1
# RUROPOLIS           1
# VARZEA ALEGRE       1
# Name: municipio, Length: 1781, dtype: int64

# %% [markdown]
# No ano de 2018 as 5 cidades que mais obtiveram acidentes em rodovias federais foram: Curitiba, São José, Brasília, Guarulhos e Palhoca.

# %%
dtran2019["municipio"].value_counts()
# Out:
# CURITIBA                   1094
# BRASILIA                   1090
# SAO JOSE                    819
# GUARULHOS                   717
# SERRA                       633
#                            ...
# DOM PEDRO                     1
# BERURI                        1
# SANTA RITA DO TOCANTINS       1
# CARACOL                       1
# GUANAMBI                      1
# Name: municipio, Length: 1767, dtype: int64

# %% [markdown]
# No ano de 2019 as 5 cidades que mais obtiveram acidentes em rodovias federais foram: Curitiba, Brasília, São José, Guarulhos e Serra.

# %%
dtran2020["municipio"].value_counts()
# Out:
# BRASILIA                    1040
# CURITIBA                     950
# GUARULHOS                    639
# SAO JOSE                     629
# PALHOCA                      593
#                             ...
# TACARATU                       1
# SAO FRANCISCO DO GUAPORE       1
# MAJOR SALES                    1
# PALMAS                         1
# IGREJA NOVA                    1
# Name: municipio, Length: 1789, dtype: int64

# %% [markdown]
# No ano de 2020 as 5 cidades que mais obtiveram acidentes em rodovias federais foram: Brasília, Curitiba, Guarulhos, São José, Palhoca.

# %% [markdown]
# <center> <h4>Quantidade de acidentes com feridos graves na Paraíba no ano de 2019</h4> </center>

# %% [markdown]
# 1º PASSO: Criar um novo Dataframe que use os dados que atendem as duas condições de ter uf = Paraíba e também que tenha 1 ou mais de 1 feridos graves.

# %%
acfgravespb = dtran2019[(dtran2019['uf']=='PB') & (dtran2019['feridos_graves']>=1)]

# %%
acfgravespb
# Out:
#              id data_inversa     dia_semana   horario  uf     br    km  \
# 47     182271.0   2019-01-01    terça-feira  04:15:00  PB  361.0  38,8
# 82     182312.0   2019-01-01    terça-feira  13:45:00  PB  230.0  18,9
# 357    182656.0   2019-01-03   quinta-feira  07:50:00  PB  101.0  81,3
# 564    183385.0   2019-01-04    sexta-feira  13:15:00  PB  230.0  17,8
# 950    183831.0   2019-01-06        domingo  21:25:00  PB  101.0    10
# ...         ...          ...            ...       ...  ..    ...   ...
# 66852  259567.0   2019-12-29        domingo  21:00:00  PB  230.0    27
# 66868  259583.0   2019-12-29        domingo  23:20:00  PB  230.0     9
# 66882  259597.0   2019-12-30  segunda-feira  03:50:00  PB  101.0  83,5
# 66954  259678.0   2019-12-30  segunda-feira  15:35:00  PB  230.0   505
# 67050  259780.0   2019-12-31    terça-feira  00:40:00  PB  101.0   122
#
#          municipio                                     causa_acidente  \
# ...

# %% [markdown]
# 2º PASSO: Contar o número de linhas que esse o Dataframe criado contém.

# %%
acfgravespb.count()
# Out:
# id                        414
# data_inversa              414
# dia_semana                414
# horario                   414
# uf                        414
# br                        414
# km                        414
# municipio                 414
# causa_acidente            414
# tipo_acidente             414
# classificacao_acidente    414
# fase_dia                  414
# sentido_via               414
# condicao_metereologica    414
# tipo_pista                414
# tracado_via               414
# uso_solo                  414
# pessoas                   414
# mortos                    414
# feridos_leves             414
# feridos_graves            414
# ilesos                    414
# ignorados                 414
# feridos                   414
# veiculos                  414
# latitude                  414
# longitude                 414
# regional                  414
# delegacia                 414
# uop                       414
# dtype: int64

# %% [markdown]
# No ano de 2019 aconteceram 414 acidentes com feridos graves na Paraíba.

# %% [markdown]
# <center> <h4>3ª Tarefa</h4> </center>

# %% [markdown]
# <center> <h4> Ranking de acidentes por estado para todos os anos</h4> </center>

# %% [markdown]
# 1º PASSO: Criar um novo Dataframe com as colunas de interesse para a criação do ranking.

# %%
d2018=dtran2018[['uf','tipo_acidente']]

# %% [markdown]
# 2º PASSO: Criar nesse novo Dataframe uma coluna contendo as quantidades referentes a quantas vezes cada tipo de acidente acontece.

# %%
da2018=d2018.value_counts().sort_values(ascending=False)

# %% [markdown]
# 3º PASSO: Considerando que vai se tornar uma Series Pandas temos que convertê-la em um Dataframe para poder executar os passos seguintes necessários.

# %%
df2018=da2018.reset_index()

# %%
df2018
# Out:
#      uf                 tipo_acidente     0
# 0    MG     Saída de leito carroçável  2144
# 1    SC              Colisão traseira  1719
# 2    PR              Colisão traseira  1559
# 3    PR     Saída de leito carroçável  1451
# 4    SC           Colisão transversal  1395
# ..   ..                           ...   ...
# 416  AC               Danos eventuais     1
# 417  AP  Queda de ocupante de veículo     1
# 418  SE         Derramamento de carga     1
# 419  AM               Danos eventuais     1
# 420  RN         Derramamento de carga     1
#
# [421 rows x 3 columns]

# %% [markdown]
# 4º PASSO: Criação de uma coluna com o ano referente que será muito útil no Dataframe que irá ser criado com a concatenação dos Dataframes referentes aos 3 anos.

# %%
df2018.insert(3, "Ano", "2018")

# %%
df2018
# Out:
#      uf                 tipo_acidente     0   Ano
# 0    MG     Saída de leito carroçável  2144  2018
# 1    SC              Colisão traseira  1719  2018
# 2    PR              Colisão traseira  1559  2018
# 3    PR     Saída de leito carroçável  1451  2018
# 4    SC           Colisão transversal  1395  2018
# ..   ..                           ...   ...   ...
# 416  AC               Danos eventuais     1  2018
# 417  AP  Queda de ocupante de veículo     1  2018
# 418  SE         Derramamento de carga     1  2018
# 419  AM               Danos eventuais     1  2018
# 420  RN         Derramamento de carga     1  2018
#
# [421 rows x 4 columns]

# %% [markdown]
# 5º PASSO: Verificação dos nomes das colunas.

# %%
df2018.columns
# Out:
# Index(['uf', 'tipo_acidente', 0, 'Ano'], dtype='object')

# %% [markdown]
# 6º PASSO: Alteração dos nomes das colunas de maneira que o novo Dataframe que irá ser criado fique mais legível e em um mesmo padrão.

# %%
df2018.rename(columns={ 0: 'Quantidade','uf':'Uf','tipo_acidente':'Tipo de Acidente'}, inplace=True)

# %%
df2018
# Out:
#      Uf              Tipo de Acidente  Quantidade   Ano
# 0    MG     Saída de leito carroçável        2144  2018
# 1    SC              Colisão traseira        1719  2018
# 2    PR              Colisão traseira        1559  2018
# 3    PR     Saída de leito carroçável        1451  2018
# 4    SC           Colisão transversal        1395  2018
# ..   ..                           ...         ...   ...
# 416  AC               Danos eventuais           1  2018
# 417  AP  Queda de ocupante de veículo           1  2018
# 418  SE         Derramamento de carga           1  2018
# 419  AM               Danos eventuais           1  2018
# 420  RN         Derramamento de carga           1  2018
#
# [421 rows x 4 columns]

# %% [markdown]
# 7º PASSO: Realização da indexação do Dataframe para colocar o Ano e o Uf como índices.

# %%
df2018.set_index(['Ano','Uf'],inplace=True)

# %% [markdown]
# Os passos descritos acima realizados para o ano de 2018 serão realizados respectivamente para os anos de 2019 e 2020.

# %%
d2019=dtran2019[['uf','tipo_acidente']]

# %%
da2019=d2019.value_counts().sort_values(ascending=False)

# %%
df2019=da2019.reset_index()

# %%
df2019.insert(3, "Ano", "2019")

# %%
df2019.columns
# Out:
# Index(['uf', 'tipo_acidente', 0, 'Ano'], dtype='object')

# %%
df2019.rename(columns={ 0: 'Quantidade','uf':'Uf','tipo_acidente':'Tipo de Acidente'}, inplace=True)

# %%
df2019
# Out:
#      Uf                 Tipo de Acidente  Quantidade   Ano
# 0    MG        Saída de leito carroçável        1837  2019
# 1    SC                 Colisão traseira        1720  2019
# 2    PR                 Colisão traseira        1619  2019
# 3    SC              Colisão transversal        1513  2019
# 4    MG                 Colisão traseira        1468  2019
# ..   ..                              ...         ...   ...
# 417  PA            Derramamento de carga           1  2019
# 418  AL            Derramamento de carga           1  2019
# 419  AP  Colisão com objeto em movimento           1  2019
# 420  RR                         Incêndio           1  2019
# 421  DF            Derramamento de carga           1  2019
#
# [422 rows x 4 columns]

# %%
df2019.set_index(['Ano','Uf'],inplace=True)

# %%
d2020=dtran2020[['uf','tipo_acidente']]

# %%
da2020=d2020.value_counts().sort_values(ascending=False)

# %%
df2020=da2020.reset_index()

# %%
df2020.insert(3, "Ano", "2020")

# %%
df2020.columns
# Out:
# Index(['uf', 'tipo_acidente', 0, 'Ano'], dtype='object')

# %%
df2020.rename(columns={ 0: 'Quantidade','uf':'Uf','tipo_acidente':'Tipo de Acidente'}, inplace=True)

# %%
df2020
# Out:
#      Uf                Tipo de Acidente  Quantidade   Ano
# 0    MG       Saída de leito carroçável        1839  2020
# 1    PR                Colisão traseira        1414  2020
# 2    PR       Saída de leito carroçável        1399  2020
# 3    SC                Colisão traseira        1368  2020
# 4    MG                Colisão traseira        1279  2020
# ..   ..                             ...         ...   ...
# 447  GO              Colisão com objeto           1  2020
# 448  CE                Eventos atípicos           1  2020
# 449  RO              Colisão com objeto           1  2020
# 450  PA              Colisão com objeto           1  2020
# 451  PA  Colisão lateral sentido oposto           1  2020
#
# [452 rows x 4 columns]

# %%
df2020.set_index(['Ano','Uf'],inplace=True)

# %% [markdown]
# 8º PASSO: Criação do novo Dataframe com o ranking de acidentes por estado para todos os anos.

# %%
dft3a = pd.concat([df2018, df2019, df2020])

# %%
dft3a
# Out:
#                        Tipo de Acidente  Quantidade
# Ano  Uf
# 2018 MG       Saída de leito carroçável        2144
#      SC                Colisão traseira        1719
#      PR                Colisão traseira        1559
#      PR       Saída de leito carroçável        1451
#      SC             Colisão transversal        1395
# ...                                 ...         ...
# 2020 GO              Colisão com objeto           1
#      CE                Eventos atípicos           1
#      RO              Colisão com objeto           1
#      PA              Colisão com objeto           1
#      PA  Colisão lateral sentido oposto           1
#
# [1295 rows x 2 columns]

# %% [markdown]
# 9ª PASSO: Gravação do conteúdo do Dataframe para um arquivo CSV.

# %%
dft3a.to_csv('C:/Users/fernando/Documents/Pâmella/Engenharia de Computação/2º Período/Estatística Aplicada a computação/Projeto/questao3a.csv', sep='\t', index=False)

# %% [markdown]
# <center> <h4>Acidentes por dia da semana para todos os anos</h4> </center>

# %% [markdown]
# 1º PASSO: Criar um novo Dataframe com as colunas de interesse para a criação do Dataframe pedido na questão.

# %%
d22018=dtran2018[['dia_semana','tipo_acidente','causa_acidente']]

# %% [markdown]
# 2º PASSO: Criação de uma nova coluna com a quantidade de acidentes por dia da semana.

# %%
db2018=d22018.value_counts(sort=False)

# %%
db2018
# Out:
# dia_semana   tipo_acidente              causa_acidente
# domingo      Atropelamento de Animal    Animais na Pista                                 208
#                                         Falta de Atenção à Condução                        5
#                                         Restrição de Visibilidade                          2
#                                         Ultrapassagem Indevida                             1
#              Atropelamento de Pedestre  Agressão Externa                                   1
#                                                                                         ...
# terça-feira  Tombamento                 Pista Escorregadia                                43
#                                         Restrição de Visibilidade                          4
#                                         Sinalização da via insuficiente ou inadequada      4
# ...

# %% [markdown]
# 3º PASSO: Como é uma series pandas, converter em Dataframe para conseguir fazer os passos necessários seguintes.

# %%
dbf2018=db2018.reset_index()

# %% [markdown]
# 4º PASSO: Inserir uma coluna com o ano que será útil para o novo Dataframe que irá ser criado.

# %%
dbf2018.insert(3, "Ano", "2018")

# %% [markdown]
# 5º PASSO: Verificação dos nomes das colunas.

# %%
dbf2018.columns
# Out:
# Index(['dia_semana', 'tipo_acidente', 'causa_acidente', 'Ano', 0], dtype='object')

# %% [markdown]
# 6º PASSO: Renomear os nomes das colunas para tornar o Dataframe mais legível e em um mesmo padrão.

# %%
dbf2018.rename(columns={ 0: 'Quantidade','dia_semana':'Dia da semana','tipo_acidente':'Tipo de Acidente','causa_acidente':'Causa do Acidente'}, inplace=True)

# %%
dbf2018
# Out:
#      Dia da semana           Tipo de Acidente  \
# 0          domingo    Atropelamento de Animal
# 1          domingo    Atropelamento de Animal
# 2          domingo    Atropelamento de Animal
# 3          domingo    Atropelamento de Animal
# 4          domingo  Atropelamento de Pedestre
# ...            ...                        ...
# 1886   terça-feira                 Tombamento
# 1887   terça-feira                 Tombamento
# 1888   terça-feira                 Tombamento
# 1889   terça-feira                 Tombamento
# 1890   terça-feira                 Tombamento
#
#                                   Causa do Acidente   Ano  Quantidade
# 0                                  Animais na Pista  2018         208
# 1                       Falta de Atenção à Condução  2018           5
# 2                         Restrição de Visibilidade  2018           2
# 3                            Ultrapassagem Indevida  2018           1
# ...

# %% [markdown]
# 7º PASSO: Tornar as colunas Ano e Dia da semana índices do Dataframe.

# %%
dbf2018.set_index(['Ano','Dia da semana'],inplace=True)

# %%
dbf2018
# Out:
#                              Tipo de Acidente  \
# Ano  Dia da semana
# 2018 domingo          Atropelamento de Animal
#      domingo          Atropelamento de Animal
#      domingo          Atropelamento de Animal
#      domingo          Atropelamento de Animal
#      domingo        Atropelamento de Pedestre
# ...                                       ...
#      terça-feira                   Tombamento
#      terça-feira                   Tombamento
#      terça-feira                   Tombamento
#      terça-feira                   Tombamento
#      terça-feira                   Tombamento
#
#                                                 Causa do Acidente  Quantidade
# Ano  Dia da semana
# 2018 domingo                                     Animais na Pista         208
#      domingo                          Falta de Atenção à Condução           5
#      domingo                            Restrição de Visibilidade           2
# ...

# %% [markdown]
# Todos os passos realizados acima para o ano de 2018 serão realizados para os anos seguintes respectivamente.

# %%
d22019=dtran2019[['dia_semana','tipo_acidente','causa_acidente']]

# %%
db2019=d22019.value_counts(sort=False)

# %%
dbf2019=db2019.reset_index()

# %%
dbf2019.insert(3, "Ano", "2019")

# %%
dbf2019.columns
# Out:
# Index(['dia_semana', 'tipo_acidente', 'causa_acidente', 'Ano', 0], dtype='object')

# %%
dbf2019.rename(columns={ 0: 'Quantidade','dia_semana':'Dia da semana','tipo_acidente':'Tipo de Acidente','causa_acidente':'Causa do Acidente'}, inplace=True)

# %%
dbf2019.set_index(['Ano','Dia da semana'],inplace=True)

# %%
dbf2019
# Out:
#                            Tipo de Acidente  \
# Ano  Dia da semana
# 2019 domingo        Atropelamento de Animal
#      domingo        Atropelamento de Animal
#      domingo        Atropelamento de Animal
#      domingo        Atropelamento de Animal
#      domingo        Atropelamento de Animal
# ...                                     ...
#      terça-feira                 Tombamento
#      terça-feira                 Tombamento
#      terça-feira                 Tombamento
#      terça-feira                 Tombamento
#      terça-feira                 Tombamento
#
#                                                     Causa do Acidente  \
# Ano  Dia da semana
# 2019 domingo                                         Animais na Pista
#      domingo                              Falta de Atenção à Condução
#      domingo                                       Ingestão de Álcool
#      domingo        Ingestão de álcool e/ou substâncias psicoativa...
# ...

# %%
d22020=dtran2020[['dia_semana','tipo_acidente','causa_acidente']]

# %%
db2020=d22020.value_counts(sort=False)

# %%
dbf2020=db2020.reset_index()

# %%
dbf2020.insert(3, "Ano", "2020")

# %%
dbf2020.columns
# Out:
# Index(['dia_semana', 'tipo_acidente', 'causa_acidente', 'Ano', 0], dtype='object')

# %%
dbf2020.rename(columns={ 0: 'Quantidade','dia_semana':'Dia da semana','tipo_acidente':'Tipo de Acidente','causa_acidente':'Causa do Acidente'}, inplace=True)

# %%
dbf2020.set_index(['Ano','Dia da semana'],inplace=True)

# %%
dbf2020
# Out:
#                            Tipo de Acidente  \
# Ano  Dia da semana
# 2020 domingo        Atropelamento de Animal
#      domingo        Atropelamento de Animal
#      domingo        Atropelamento de Animal
#      domingo        Atropelamento de Animal
#      domingo        Atropelamento de Animal
# ...                                     ...
#      terça-feira                 Tombamento
#      terça-feira                 Tombamento
#      terça-feira                 Tombamento
#      terça-feira                 Tombamento
#      terça-feira                 Tombamento
#
#                                                     Causa do Acidente  \
# Ano  Dia da semana
# 2020 domingo                                         Agressão Externa
#      domingo                                         Animais na Pista
#      domingo        Desobediência às normas de trânsito pelo condutor
#      domingo                              Falta de Atenção à Condução
# ...

# %% [markdown]
# 8º PASSO: Concatenação dos Dataframes criados para os 3 anos para criar um novo Dataframe referente aos acidentes por dia da semana para todos os anos.

# %%
dft3b = pd.concat([dbf2018, dbf2019, dbf2020])

# %%
dft3b
# Out:
#                              Tipo de Acidente  \
# Ano  Dia da semana
# 2018 domingo          Atropelamento de Animal
#      domingo          Atropelamento de Animal
#      domingo          Atropelamento de Animal
#      domingo          Atropelamento de Animal
#      domingo        Atropelamento de Pedestre
# ...                                       ...
# 2020 terça-feira                   Tombamento
#      terça-feira                   Tombamento
#      terça-feira                   Tombamento
#      terça-feira                   Tombamento
#      terça-feira                   Tombamento
#
#                                                 Causa do Acidente  Quantidade
# Ano  Dia da semana
# 2018 domingo                                     Animais na Pista         208
#      domingo                          Falta de Atenção à Condução           5
#      domingo                            Restrição de Visibilidade           2
# ...

# %% [markdown]
# 9º PASSO: Gravação do conteúdo do Dataframe para um arquivo CSV.

# %%
dft3b.to_csv('C:/Users/fernando/Documents/Pâmella/Engenharia de Computação/2º Período/Estatística Aplicada a computação/Projeto/questao3b.csv', sep='\t', index=False)

# %% [markdown]
# <center> <h4>4ª Tarefa</h4> </center>

# %% [markdown]
# <center> <h4>Causa mais frequente e a mais rara de acidentes registrados nos três anos</h4> </center>

# %% [markdown]
# 1º PASSO: Fazer uma contagem no Dataframe criado na questão 3 letra b e verificar o que se pede.

# %%
dft3b.value_counts()
# Out:
# Tipo de Acidente                 Causa do Acidente                              Quantidade
# Colisão frontal                  Animais na Pista                               2             12
# Danos eventuais                  Avarias e/ou desgaste excessivo no pneu        1             12
# Colisão com objeto em movimento  Velocidade Incompatível                        1             12
# Capotamento                      Sinalização da via insuficiente ou inadequada  1             11
# Engavetamento                    Sinalização da via insuficiente ou inadequada  1             11
#                                                                                               ..
# Colisão traseira                 Sinalização da via insuficiente ou inadequada  2              1
# Colisão frontal                  Pista Escorregadia                             22             1
# Colisão traseira                 Restrição de Visibilidade                      22             1
# ...

# %% [markdown]
# Causas mais frequentes: Animais na pista, Avarias e/ou desgaste excessivo no pneu e Velocidade Incompatível.

# %% [markdown]
# Causas mais raras: Sinalização da via insuficiente ou inadequada, Pista Escorregadia, Restrição de Visibilidade e Falta de Atenção à Condução.

# %% [markdown]
# <center> <h4>Proporção de pessoas ilesas e de feridos graves por mês em cada um dos anos
# considerados</h4> </center>

# %% [markdown]
# 1º PASSO: Verificação das colunas existentes no ano de 2018 para saber quais serão necessárias para resolver o problema proposto.

# %% [markdown]
# E o tipo de acidente que menos aconteceu foi tombamento.

# %%
dtran2018.columns
# Out:
# Index(['id', 'data_inversa', 'dia_semana', 'horario', 'uf', 'br', 'km',
#        'municipio', 'causa_acidente', 'tipo_acidente',
#        'classificacao_acidente', 'fase_dia', 'sentido_via',
#        'condicao_metereologica', 'tipo_pista', 'tracado_via', 'uso_solo',
#        'pessoas', 'mortos', 'feridos_leves', 'feridos_graves', 'ilesos',
#        'ignorados', 'feridos', 'veiculos', 'latitude', 'longitude', 'regional',
#        'delegacia', 'uop'],
#       dtype='object')

# %% [markdown]
# 2º PASSO: Criação de uma nova coluna com os meses.

# %%
dtran2018['Mes'] = pd.DatetimeIndex(dtran2018['data_inversa']).month

# %%
dtran2018
# Out:
#              id data_inversa     dia_semana   horario  uf     br     km  \
# 0       99973.0   2018-01-01  segunda-feira  00:20:00  RJ  116.0  303,5
# 1       99976.0   2018-01-01  segunda-feira  00:40:00  SC  282.0    0,4
# 2       99977.0   2018-01-01  segunda-feira  00:30:00  RJ  493.0      1
# 3       99981.0   2018-01-01  segunda-feira  01:15:00  RS  386.0    134
# 4       99982.0   2018-01-01  segunda-feira  00:20:00  RS  293.0  151,7
# ...         ...          ...            ...       ...  ..    ...    ...
# 69290  252256.0   2018-12-24  segunda-feira  09:15:00  PI  343.0  263,1
# 69291  252652.0   2018-12-12   quarta-feira  07:00:00  BA  101.0    321
# 69292  252801.0   2018-11-15   quinta-feira  10:48:00  SP  116.0    529
# 69293  253040.0   2018-11-23    sexta-feira  19:30:00  RS  472.0  573,5
# 69294  253078.0   2018-10-01  segunda-feira  04:31:00  GO   40.0      9
#
#                        municipio  \
# 0                        RESENDE
# ...

# %% [markdown]
# 3º PASSO: Criação de um novo Dataframe apenas com as colunas necessárias para o ano de 2018.

# %%
df4b2018 = dtran2018[['Mes', 'ilesos', 'feridos_graves', 'pessoas']].sort_values(by='Mes')

# %%
df4b2018
# Out:
#        Mes  ilesos  feridos_graves  pessoas
# 0        1       1               4        5
# 4633     1       1               0        2
# 4632     1       0               0        1
# 4631     1       1               0        1
# 4630     1       1               0        1
# ...    ...     ...             ...      ...
# 64651   12       0               0        1
# 64650   12       0               0        2
# 64649   12       1               0        2
# 64647   12       0               0        2
# 65370   12       1               0        2
#
# [69295 rows x 4 columns]

# %% [markdown]
# 4º PASSO: Renomear as colunas para ficarem mais legíveis e seguirem o mesmo padrão.

# %%
df4b2018.rename(columns={'feridos_graves': 'Feridos Graves','ilesos':'Ilesos','pessoas':'Total de Pessoas'}, inplace=True)

# %% [markdown]
# Seguir os passos descritos acima para criar os mesmos Dataframes para os repectivos anos seguintes.

# %%
dtran2019['Mes'] = pd.DatetimeIndex(dtran2019['data_inversa']).month

# %%
df4b2019 = dtran2019[['Mes', 'ilesos', 'feridos_graves', 'pessoas']].sort_values(by='Mes')

# %%
df4b2019.rename(columns={'feridos_graves': 'Feridos Graves','ilesos':'Ilesos','pessoas':'Total de Pessoas'}, inplace=True)

# %%
dtran2020['Mes'] = pd.DatetimeIndex(dtran2020['data_inversa']).month

# %%
df4b2020 = dtran2020[['Mes', 'ilesos', 'feridos_graves', 'pessoas']].sort_values(by='Mes')

# %%
df4b2020.rename(columns={'feridos_graves': 'Feridos Graves','ilesos':'Ilesos','pessoas':'Total de Pessoas'}, inplace=True)

# %% [markdown]
# 5º PASSO: Criar um novo Dataframe para o mês de janeiro com todos os anos.

# %%
jan2018 = df4b2018[df4b2018['Mes']==1]

# %%
jan2019 = df4b2019[df4b2019['Mes']==1]

# %%
jan2020 = df4b2020[df4b2020['Mes']==1]

# %% [markdown]
# 6º PASSO: Calcular a quantidade de ilesos em janeiro de todos os anos.

# %%
ilesosjan2018 = jan2018['Ilesos'].sum()

# %%
ilesosjan2019 = jan2019['Ilesos'].sum()

# %%
ilesosjan2020 = jan2020['Ilesos'].sum()

# %% [markdown]
# 7º PASSO: Calcular a quantidade total de pessoas envolvidas em acidentes no mês de janeiro em todos os anos.

# %%
tpjan2018 = jan2018['Total de Pessoas'].sum()

# %%
tpjan2019 = jan2019['Total de Pessoas'].sum()

# %%
tpjan2020 = jan2020['Total de Pessoas'].sum()

# %% [markdown]
# 8º PASSO: Calcular a proporção de ilesos em janeiro de todos os anos.

# %%
pilesosjan2018 = round((ilesosjan2018/tpjan2018)*100, 2)

# %%
pilesosjan2018
# Out:
# 51.33

# %%
pilesosjan2019 = round((ilesosjan2019/tpjan2019)*100, 2)

# %%
pilesosjan2019
# Out:
# 42.42

# %%
pilesosjan2020 = round((ilesosjan2020/tpjan2020)*100, 2)

# %%
pilesosjan2020
# Out:
# 41.56

# %% [markdown]
# 9º PASSO: Calcular a quantidade de feridos graves em janeiro de todos os anos.

# %%
fgravesjan2018 = jan2018['Feridos Graves'].sum()

# %%
fgravesjan2019 = jan2019['Feridos Graves'].sum()

# %%
fgravesjan2020 = jan2020['Feridos Graves'].sum()

# %% [markdown]
# 10º PASSO: Calcular a proporção de feridos graves em janeiro de todos os anos.

# %%
pfgravesjan2018 = round((fgravesjan2018/tpjan2018)*100, 2)

# %%
pfgravesjan2018
# Out:
# 9.06

# %%
pfgravesjan2019 = round((fgravesjan2019/tpjan2019)*100, 2)

# %%
pfgravesjan2019
# Out:
# 11.33

# %%
pfgravesjan2020 = round((fgravesjan2020/tpjan2020)*100, 2)

# %%
pfgravesjan2020
# Out:
# 10.75

# %% [markdown]
# Todos os passos descritos acima serão feitos para calcular a proporção para os respectivos meses seguintes.

# %%
fev2018 = df4b2018[df4b2018['Mes']==2]

# %%
fev2019 = df4b2019[df4b2019['Mes']==2]

# %%
fev2020 = df4b2020[df4b2020['Mes']==2]

# %%
ilesosfev2018 = fev2018['Ilesos'].sum()

# %%
ilesosfev2019 = fev2019['Ilesos'].sum()

# %%
ilesosfev2020 = fev2020['Ilesos'].sum()

# %%
tpfev2018 = fev2018['Total de Pessoas'].sum()

# %%
tpfev2019 = fev2019['Total de Pessoas'].sum()

# %%
tpfev2020 = fev2020['Total de Pessoas'].sum()

# %%
pilesosfev2018 = round((ilesosfev2018/tpfev2018)*100, 2)

# %%
pilesosfev2018
# Out:
# 49.83

# %%
pilesosfev2019 = round((ilesosfev2019/tpfev2019)*100, 2)

# %%
pilesosfev2019
# Out:
# 42.41

# %%
pilesosfev2020 = round((ilesosfev2020/tpfev2020)*100, 2)

# %%
pilesosfev2020
# Out:
# 42.0

# %%
fgravesfev2018 = fev2018['Feridos Graves'].sum()

# %%
fgravesfev2019 = fev2019['Feridos Graves'].sum()

# %%
fgravesfev2020 = fev2020['Feridos Graves'].sum()

# %%
pfgravesfev2018 = round((fgravesfev2018/tpfev2018)*100, 2)

# %%
pfgravesfev2018
# Out:
# 9.22

# %%
pfgravesfev2019 = round((fgravesfev2019/tpfev2019)*100, 2)

# %%
pfgravesfev2019
# Out:
# 10.68

# %%
pfgravesfev2020 = round((fgravesfev2020/tpfev2020)*100, 2)

# %%
pfgravesfev2020
# Out:
# 11.14

# %%
mar2018 = df4b2018[df4b2018['Mes']==3]
mar2019 = df4b2019[df4b2019['Mes']==3]
mar2020 = df4b2020[df4b2020['Mes']==3]

# %%
ilesosmar2018 = mar2018['Ilesos'].sum()
ilesosmar2019 = mar2019['Ilesos'].sum()
ilesosmar2020 = mar2020['Ilesos'].sum()

# %%
tpmar2018 = mar2018['Total de Pessoas'].sum()
tpmar2019 = mar2019['Total de Pessoas'].sum()
tpmar2020 = mar2020['Total de Pessoas'].sum()

# %%
pilesosmar2018 = round((ilesosmar2018/tpmar2018)*100, 2)
pilesosmar2018
# Out:
# 48.15

# %%
pilesosmar2019 = round((ilesosmar2019/tpmar2019)*100, 2)
pilesosmar2019
# Out:
# 43.32

# %%
pilesosmar2020 = round((ilesosmar2020/tpmar2020)*100, 2)
pilesosmar2020
# Out:
# 40.1

# %%
fgravesmar2018 = mar2018['Feridos Graves'].sum()
fgravesmar2019 = mar2019['Feridos Graves'].sum()
fgravesmar2020 = mar2020['Feridos Graves'].sum()

# %%
pfgravesmar2018 = round((fgravesmar2018/tpmar2018)*100, 2)
pfgravesmar2018
# Out:
# 10.19

# %%
pfgravesmar2019 = round((fgravesmar2019/tpmar2019)*100, 2)
pfgravesmar2019
# Out:
# 11.46

# %%
pfgravesmar2020 = round((fgravesmar2020/tpmar2020)*100, 2)
pfgravesmar2020
# Out:
# 11.26

# %%
abr2018 = df4b2018[df4b2018['Mes']==4]
abr2019 = df4b2019[df4b2019['Mes']==4]
abr2020 = df4b2020[df4b2020['Mes']==4]

# %%
ilesosabr2018 = abr2018['Ilesos'].sum()
ilesosabr2019 = abr2019['Ilesos'].sum()
ilesosabr2020 = abr2020['Ilesos'].sum()

# %%
tpabr2018 = abr2018['Total de Pessoas'].sum()
tpabr2019 = abr2019['Total de Pessoas'].sum()
tpabr2020 = abr2020['Total de Pessoas'].sum()

# %%
pilesosabr2018 = round((ilesosabr2018/tpabr2018)*100, 2)
pilesosabr2018
# Out:
# 43.02

# %%
pilesosabr2019 = round((ilesosabr2019/tpabr2019)*100, 2)
pilesosabr2019
# Out:
# 41.57

# %%
pilesosabr2020 = round((ilesosabr2020/tpabr2020)*100, 2)
pilesosabr2020
# Out:
# 37.63

# %%
fgravesabr2018 = abr2018['Feridos Graves'].sum()
fgravesabr2019 = abr2019['Feridos Graves'].sum()
fgravesabr2020 = abr2020['Feridos Graves'].sum()

# %%
pfgravesabr2018 = round((fgravesabr2018/tpabr2018)*100, 2)
pfgravesabr2018
# Out:
# 11.28

# %%
pfgravesabr2019 = round((fgravesabr2019/tpabr2019)*100, 2)
pfgravesabr2019
# Out:
# 10.6

# %%
pfgravesabr2020 = round((fgravesabr2020/tpabr2020)*100, 2)
pfgravesabr2020
# Out:
# 11.79

# %%
mai2018 = df4b2018[df4b2018['Mes']==5]
mai2019 = df4b2019[df4b2019['Mes']==5]
mai2020 = df4b2020[df4b2020['Mes']==5]

# %%
ilesosmai2018 = mai2018['Ilesos'].sum()
ilesosmai2019 = mai2019['Ilesos'].sum()
ilesosmai2020 = mai2020['Ilesos'].sum()

# %%
tpmai2018 = mai2018['Total de Pessoas'].sum()
tpmai2019 = mai2019['Total de Pessoas'].sum()
tpmai2020 = mai2020['Total de Pessoas'].sum()

# %%
pilesosmai2018 = round((ilesosmai2018/tpmai2018)*100, 2)
pilesosmai2018
# Out:
# 42.22

# %%
pilesosmai2019 = round((ilesosmai2019/tpmai2019)*100, 2)
pilesosmai2019
# Out:
# 41.52

# %%
pilesosmai2020 = round((ilesosmai2020/tpmai2020)*100, 2)
pilesosmai2020
# Out:
# 40.13

# %%
fgravesmai2018 = mai2018['Feridos Graves'].sum()
fgravesmai2019 = mai2019['Feridos Graves'].sum()
fgravesmai2020 = mai2020['Feridos Graves'].sum()

# %%
pfgravesmai2018 = round((fgravesmai2018/tpmai2018)*100, 2)
pfgravesmai2018
# Out:
# 11.45

# %%
pfgravesmai2019 = round((fgravesmai2019/tpmai2019)*100, 2)
pfgravesmai2019
# Out:
# 12.08

# %%
pfgravesmai2020 = round((fgravesmai2020/tpmai2020)*100, 2)
pfgravesmai2020
# Out:
# 11.59

# %%
jun2018 = df4b2018[df4b2018['Mes']==6]
jun2019 = df4b2019[df4b2019['Mes']==6]
jun2020 = df4b2020[df4b2020['Mes']==6]

# %%
ilesosjun2018 = jun2018['Ilesos'].sum()
ilesosjun2019 = jun2019['Ilesos'].sum()
ilesosjun2020 = jun2020['Ilesos'].sum()

# %%
tpjun2018 = jun2018['Total de Pessoas'].sum()
tpjun2019 = jun2019['Total de Pessoas'].sum()
tpjun2020 = jun2020['Total de Pessoas'].sum()

# %%
pilesosjun2018 = round((ilesosjun2018/tpjun2018)*100, 2)
pilesosjun2018
# Out:
# 42.51

# %%
pilesosjun2019 = round((ilesosjun2019/tpjun2019)*100, 2)
pilesosjun2019
# Out:
# 42.38

# %%
pilesosjun2020 = round((ilesosjun2020/tpjun2020)*100, 2)
pilesosjun2020
# Out:
# 42.33

# %%
fgravesjun2018 = jun2018['Feridos Graves'].sum()
fgravesjun2019 = jun2019['Feridos Graves'].sum()
fgravesjun2020 = jun2020['Feridos Graves'].sum()

# %%
pfgravesjun2018 = round((fgravesjun2018/tpjun2018)*100, 2)
pfgravesjun2018
# Out:
# 11.64

# %%
pfgravesjun2019 = round((fgravesjun2019/tpjun2019)*100, 2)
pfgravesjun2019
# Out:
# 12.16

# %%
pfgravesjun2020 = round((fgravesjun2020/tpjun2020)*100, 2)
pfgravesjun2020
# Out:
# 11.59

# %%
jul2018 = df4b2018[df4b2018['Mes']==7]
jul2019 = df4b2019[df4b2019['Mes']==7]
jul2020 = df4b2020[df4b2020['Mes']==7]

# %%
ilesosjul2018 = jul2018['Ilesos'].sum()
ilesosjul2019 = jul2019['Ilesos'].sum()
ilesosjul2020 = jul2020['Ilesos'].sum()

# %%
tpjul2018 = jul2018['Total de Pessoas'].sum()
tpjul2019 = jul2019['Total de Pessoas'].sum()
tpjul2020 = jul2020['Total de Pessoas'].sum()

# %%
pilesosjul2018 = round((ilesosjul2018/tpjul2018)*100, 2)
pilesosjul2018
# Out:
# 43.75

# %%
pilesosjul2019 = round((ilesosjul2019/tpjul2019)*100, 2)
pilesosjul2019
# Out:
# 43.68

# %%
pilesosjul2020 = round((ilesosjul2020/tpjul2020)*100, 2)
pilesosjul2020
# Out:
# 42.43

# %%
fgravesjul2018 = jul2018['Feridos Graves'].sum()
fgravesjul2019 = jul2019['Feridos Graves'].sum()
fgravesjul2020 = jul2020['Feridos Graves'].sum()

# %%
pfgravesjul2018 = round((fgravesjul2018/tpjul2018)*100, 2)
pfgravesjul2018
# Out:
# 11.03

# %%
pfgravesjul2019 = round((fgravesjul2019/tpjul2019)*100, 2)
pfgravesjul2019
# Out:
# 11.67

# %%
pfgravesjul2020 = round((fgravesjul2020/tpjul2020)*100, 2)
pfgravesjul2020
# Out:
# 10.86

# %%
Ago2018 = df4b2018[df4b2018['Mes']==8]
Ago2019 = df4b2019[df4b2019['Mes']==8]
Ago2020 = df4b2020[df4b2020['Mes']==8]

# %%
ilesosAgo2018 = Ago2018['Ilesos'].sum()
ilesosAgo2019 = Ago2019['Ilesos'].sum()
ilesosAgo2020 = Ago2020['Ilesos'].sum()

# %%
tpAgo2018 = Ago2018['Total de Pessoas'].sum()
tpAgo2019 = Ago2019['Total de Pessoas'].sum()
tpAgo2020 = Ago2020['Total de Pessoas'].sum()

# %%
pilesosAgo2018 = round((ilesosAgo2018/tpAgo2018)*100, 2)
pilesosAgo2018
# Out:
# 42.71

# %%
pilesosAgo2019 = round((ilesosAgo2019/tpAgo2019)*100, 2)
pilesosAgo2019
# Out:
# 41.31

# %%
pilesosAgo2020 = round((ilesosAgo2020/tpAgo2020)*100, 2)
pilesosAgo2020
# Out:
# 42.34

# %%
fgravesAgo2018 = Ago2018['Feridos Graves'].sum()
fgravesAgo2019 = Ago2019['Feridos Graves'].sum()
fgravesAgo2020 = Ago2020['Feridos Graves'].sum()

# %%
pfgravesAgo2018 = round((fgravesAgo2018/tpAgo2018)*100, 2)
pfgravesAgo2018
# Out:
# 10.64

# %%
pfgravesAgo2019 = round((fgravesAgo2019/tpAgo2019)*100, 2)
pfgravesAgo2019
# Out:
# 11.67

# %%
pfgravesAgo2020 = round((fgravesAgo2020/tpAgo2020)*100, 2)
pfgravesAgo2020
# Out:
# 11.92

# %%
set2018 = df4b2018[df4b2018['Mes']==9]
set2019 = df4b2019[df4b2019['Mes']==9]
set2020 = df4b2020[df4b2020['Mes']==9]

# %%
ilesosset2018 = set2018['Ilesos'].sum()
ilesosset2019 = set2019['Ilesos'].sum()
ilesosset2020 = set2020['Ilesos'].sum()

# %%
tpset2018 = set2018['Total de Pessoas'].sum()
tpset2019 = set2019['Total de Pessoas'].sum()
tpset2020 = set2020['Total de Pessoas'].sum()

# %%
pilesosset2018 = round((ilesosset2018/tpset2018)*100, 2)
pilesosset2018
# Out:
# 42.07

# %%
pilesosset2019 = round((ilesosset2019/tpset2019)*100, 2)
pilesosset2019
# Out:
# 42.11

# %%
pilesosset2020 = round((ilesosset2020/tpset2020)*100, 2)
pilesosset2020
# Out:
# 41.6

# %%
fgravesset2018 = set2018['Feridos Graves'].sum()
fgravesset2019 = set2019['Feridos Graves'].sum()
fgravesset2020 = set2020['Feridos Graves'].sum()

# %%
pfgravesset2018 = round((fgravesset2018/tpset2018)*100, 2)
pfgravesset2018
# Out:
# 11.55

# %%
pfgravesset2019 = round((fgravesset2019/tpset2019)*100, 2)
pfgravesset2019
# Out:
# 11.07

# %%
pfgravesset2020 = round((fgravesset2020/tpset2020)*100, 2)
pfgravesset2020
# Out:
# 11.74

# %%
out2018 = df4b2018[df4b2018['Mes']==10]
out2019 = df4b2019[df4b2019['Mes']==10]
out2020 = df4b2020[df4b2020['Mes']==10]

# %%
ilesosout2018 = out2018['Ilesos'].sum()
ilesosout2019 = out2019['Ilesos'].sum()
ilesosout2020 = out2020['Ilesos'].sum()

# %%
tpout2018 = out2018['Total de Pessoas'].sum()
tpout2019 = out2019['Total de Pessoas'].sum()
tpout2020 = out2020['Total de Pessoas'].sum()

# %%
pilesosout2018 = round((ilesosout2018/tpout2018)*100, 2)
pilesosout2018
# Out:
# 43.02

# %%
pilesosout2019 = round((ilesosout2019/tpout2019)*100, 2)
pilesosout2019
# Out:
# 41.89

# %%
pilesosout2020 = round((ilesosout2020/tpout2020)*100, 2)
pilesosout2020
# Out:
# 41.1

# %%
fgravesout2018 = out2018['Feridos Graves'].sum()
fgravesout2019 = out2019['Feridos Graves'].sum()
fgravesout2020 = out2020['Feridos Graves'].sum()

# %%
pfgravesout2018 = round((fgravesout2018/tpout2018)*100, 2)
pfgravesout2018
# Out:
# 11.26

# %%
pfgravesout2019 = round((fgravesout2019/tpout2019)*100, 2)
pfgravesout2019
# Out:
# 11.98

# %%
pfgravesout2020 = round((fgravesout2020/tpout2020)*100, 2)
pfgravesout2020
# Out:
# 11.97

# %%
nov2018 = df4b2018[df4b2018['Mes']==11]
nov2019 = df4b2019[df4b2019['Mes']==11]
nov2020 = df4b2020[df4b2020['Mes']==11]

# %%
ilesosnov2018 = nov2018['Ilesos'].sum()
ilesosnov2019 = nov2019['Ilesos'].sum()
ilesosnov2020 = nov2020['Ilesos'].sum()

# %%
tpnov2018 = nov2018['Total de Pessoas'].sum()
tpnov2019 = nov2019['Total de Pessoas'].sum()
tpnov2020 = nov2020['Total de Pessoas'].sum()

# %%
pilesosnov2018 = round((ilesosnov2018/tpnov2018)*100, 2)
pilesosnov2018
# Out:
# 43.34

# %%
pilesosnov2019 = round((ilesosnov2019/tpnov2019)*100, 2)
pilesosnov2019
# Out:
# 42.58

# %%
pilesosnov2020 = round((ilesosnov2020/tpnov2020)*100, 2)
pilesosnov2020
# Out:
# 40.7

# %%
fgravesnov2018 = nov2018['Feridos Graves'].sum()
fgravesnov2019 = nov2019['Feridos Graves'].sum()
fgravesnov2020 = nov2020['Feridos Graves'].sum()

# %%
pfgravesnov2018 = round((fgravesnov2018/tpnov2018)*100, 2)
pfgravesnov2018
# Out:
# 11.54

# %%
pfgravesnov2019 = round((fgravesnov2019/tpnov2019)*100, 2)
pfgravesnov2019
# Out:
# 11.1

# %%
pfgravesnov2020 = round((fgravesnov2020/tpnov2020)*100, 2)
pfgravesnov2020
# Out:
# 12.04

# %%
dez2018 = df4b2018[df4b2018['Mes']==12]
dez2019 = df4b2019[df4b2019['Mes']==12]
dez2020 = df4b2020[df4b2020['Mes']==12]

# %%
ilesosdez2018 = dez2018['Ilesos'].sum()
ilesosdez2019 = dez2019['Ilesos'].sum()
ilesosdez2020 = dez2020['Ilesos'].sum()

# %%
tpdez2018 = dez2018['Total de Pessoas'].sum()
tpdez2019 = dez2019['Total de Pessoas'].sum()
tpdez2020 = dez2020['Total de Pessoas'].sum()

# %%
pilesosdez2018 = round((ilesosdez2018/tpdez2018)*100, 2)
pilesosdez2018
# Out:
# 43.29

# %%
pilesosdez2019 = round((ilesosdez2019/tpdez2019)*100, 2)
pilesosdez2019
# Out:
# 42.23

# %%
pilesosdez2020 = round((ilesosdez2020/tpdez2020)*100, 2)
pilesosdez2020
# Out:
# 41.23

# %%
fgravesdez2018 = dez2018['Feridos Graves'].sum()
fgravesdez2019 = dez2019['Feridos Graves'].sum()
fgravesdez2020 = dez2020['Feridos Graves'].sum()

# %%
pfgravesdez2018 = round((fgravesdez2018/tpdez2018)*100, 2)
pfgravesdez2018
# Out:
# 10.81

# %%
pfgravesdez2019 = round((fgravesdez2019/tpdez2019)*100, 2)
pfgravesdez2019
# Out:
# 11.44

# %%
pfgravesdez2020 = round((fgravesdez2020/tpdez2020)*100, 2)
pfgravesdez2020
# Out:
# 12.2

# %% [markdown]
# <center> <h4>Efeitos da pandemia na incidência de acidentes nas rodovias federais</h4> </center>

# %% [markdown]
# 1º PASSO: Vamos utilizar os Dataframes alterados na questão anterior, ou seja, a coluna Mes será útil para fazer essa análise.

# %%
dtran2018
# Out:
#              id data_inversa     dia_semana   horario  uf     br     km  \
# 0       99973.0   2018-01-01  segunda-feira  00:20:00  RJ  116.0  303,5
# 1       99976.0   2018-01-01  segunda-feira  00:40:00  SC  282.0    0,4
# 2       99977.0   2018-01-01  segunda-feira  00:30:00  RJ  493.0      1
# 3       99981.0   2018-01-01  segunda-feira  01:15:00  RS  386.0    134
# 4       99982.0   2018-01-01  segunda-feira  00:20:00  RS  293.0  151,7
# ...         ...          ...            ...       ...  ..    ...    ...
# 69290  252256.0   2018-12-24  segunda-feira  09:15:00  PI  343.0  263,1
# 69291  252652.0   2018-12-12   quarta-feira  07:00:00  BA  101.0    321
# 69292  252801.0   2018-11-15   quinta-feira  10:48:00  SP  116.0    529
# 69293  253040.0   2018-11-23    sexta-feira  19:30:00  RS  472.0  573,5
# 69294  253078.0   2018-10-01  segunda-feira  04:31:00  GO   40.0      9
#
#                        municipio  \
# 0                        RESENDE
# ...

# %% [markdown]
# 2º PASSO: Criação de novos Dataframes a partir do mês de março de 2018 para comparar com os anos seguintes a quantidade de acidentes em cada mês para cada Dataframe seguinte para analisar as consequências da pandemia nos dados analisados.

# %%
amar2018 = dtran2018[dtran2018['Mes']==3]

# %%
amar2018
# Out:
#              id data_inversa    dia_semana   horario  uf     br     km  \
# 12712  114909.0   2018-03-01  quinta-feira  00:50:00  RJ  101.0     44
# 12713  114910.0   2018-03-01  quinta-feira  00:01:00  RS  290.0    119
# 12714  114911.0   2018-03-01  quinta-feira  01:40:00  PR  376.0    505
# 12717  114914.0   2018-03-01  quinta-feira  02:40:00  MG   40.0    584
# 12718  114915.0   2018-03-01  quinta-feira  03:09:00  RJ  116.0     96
# ...         ...          ...           ...       ...  ..    ...    ...
# 69225  234925.0   2018-03-17        sábado  06:40:00  PA  316.0      2
# 69251  240085.0   2018-03-21  quarta-feira  06:30:00  ES  101.0  263,1
# 69270  245115.0   2018-03-11       domingo  16:30:00  SC  101.0  353,2
# 69274  246071.0   2018-03-02   sexta-feira  23:20:00  RJ  116.0    184
# 69283  249491.0   2018-03-20   terça-feira  19:55:00  SP  116.0    151
#
#                    municipio                      causa_acidente  \
# ...

# %%
amar2019 = dtran2019[dtran2019['Mes']==3]
amar2019
# Out:
#              id data_inversa    dia_semana   horario  uf     br     km  \
# 9756   194205.0   2019-03-01   sexta-feira  00:00:00  PR  376.0  667,3
# 9761   194210.0   2019-03-01   sexta-feira  00:30:00  PR  277.0     82
# 9763   194215.0   2019-03-01   sexta-feira  00:46:00  PR  376.0    239
# 9764   194216.0   2019-03-01   sexta-feira  01:00:00  RS  116.0  520,9
# 9765   194217.0   2019-03-01   sexta-feira  01:50:00  PR  376.0    179
# ...         ...          ...           ...       ...  ..    ...    ...
# 64922  257463.0   2019-03-30        sábado  18:00:00  MG  262.0  456,2
# 66458  259139.0   2019-03-02        sábado  14:30:00  MG   50.0    153
# 67365  264183.0   2019-03-09        sábado  15:30:00  BA  324.0    512
# 67368  264265.0   2019-03-28  quinta-feira  10:30:00  SC  282.0    497
# 67388  264771.0   2019-03-02        sábado  05:40:00  GO   70.0      3
#
#                    municipio  \
# 9756               GUARATUBA
# 9761                CURITIBA
# ...

# %%
amar2020 = dtran2020[dtran2020['Mes']==3]
amar2020
# Out:
#              id data_inversa    dia_semana   horario  uf     br     km  \
# 10649  272493.0   2020-03-01       domingo  00:00:00  GO   60.0    387
# 10652  272496.0   2020-03-01       domingo  00:00:00  PI  316.0    288
# 10653  272497.0   2020-03-01       domingo  00:30:00  RJ  101.0    265
# 10654  272498.0   2020-03-01       domingo  01:00:00  SP  116.0    271
# 10657  272501.0   2020-03-01       domingo  01:00:00  MG   40.0  786,7
# ...         ...          ...           ...       ...  ..    ...    ...
# 63498  358486.0   2020-03-08       domingo  11:15:00  MG  459.0   64,9
# 63500  358876.0   2020-03-05  quinta-feira  10:50:00  PE  232.0  408,7
# 63513  360466.0   2020-03-14        sábado  14:40:00  RJ  101.0    243
# 63534  364030.0   2020-03-13   sexta-feira  22:40:00  SC  101.0    158
# 63543  364615.0   2020-03-20   sexta-feira  09:00:00  RN  304.0  171,8
#
#                 municipio                                     causa_acidente  \
# ...

# %% [markdown]
# Houve redução do número de acidentes no mês Março de 2020 início da Pandemia.

# %%
aabr2018 = dtran2018[dtran2018['Mes']==4]
aabr2018
# Out:
#              id data_inversa dia_semana   horario  uf     br     km  \
# 19313  122403.0   2018-04-01    domingo  00:50:00  PR  277.0     75
# 19315  122405.0   2018-04-01    domingo  01:30:00  PR  376.0    135
# 19316  122406.0   2018-04-01    domingo  01:35:00  RS  116.0    365
# 19317  122408.0   2018-04-01    domingo  00:15:00  GO   60.0    128
# 19318  122409.0   2018-04-01    domingo  00:15:00  MG  116.0  414,5
# ...         ...          ...        ...       ...  ..    ...    ...
# 69181  225368.0   2018-04-15    domingo  09:00:00  MA  135.0  128,8
# 69184  225444.0   2018-04-14     sábado  13:30:00  MT   70.0      2
# 69200  229020.0   2018-04-01    domingo  18:35:00  SP  116.0  112,8
# 69202  229161.0   2018-04-07     sábado  20:00:00  RJ  101.0  280,8
# 69209  231498.0   2018-04-01    domingo  19:23:00  BA  324.0    515
#
#                   municipio  \
# 19313  SAO JOSE DOS PINHAIS
# 19315        NOVA ESPERANCA
# 19316                 TAPES
# 19317           GOIANAPOLIS
# ...

# %%
aabr2019 = dtran2019[dtran2019['Mes']==4]
aabr2019
# Out:
#              id data_inversa     dia_semana   horario  uf     br     km  \
# 15272  200475.0   2019-04-01  segunda-feira  00:00:00  ES  101.0  144,5
# 15278  200483.0   2019-04-01  segunda-feira  00:45:00  MG  381.0    448
# 15279  200484.0   2019-04-01  segunda-feira  01:05:00  ES  101.0  263,8
# 15281  200486.0   2019-04-01  segunda-feira  00:50:00  MT  163.0    837
# 15282  200487.0   2019-04-01  segunda-feira  01:40:00  SC  101.0    132
# ...         ...          ...            ...       ...  ..    ...    ...
# 67394  264971.0   2019-04-16    terça-feira  18:30:00  RS  116.0    269
# 67411  265537.0   2019-04-22  segunda-feira  10:15:00  MG   50.0    123
# 67432  265995.0   2019-04-20         sábado  05:10:00  BA  407.0  203,6
# 67433  266003.0   2019-04-07        domingo  23:30:00  PI  222.0     35
# 67438  266153.0   2019-04-23    terça-feira  07:00:00  PE  101.0    156
#
#                 municipio                                     causa_acidente  \
# ...

# %%
aabr2020 = dtran2020[dtran2020['Mes']==4]
aabr2020
# Out:
#              id data_inversa    dia_semana   horario  uf     br     km  \
# 15363  277905.0   2020-04-01  quarta-feira  00:50:00  ES  101.0  267,6
# 15364  277906.0   2020-04-01  quarta-feira  03:15:00  SP  153.0     61
# 15365  277907.0   2020-04-01  quarta-feira  03:30:00  SC  101.0    119
# 15366  277909.0   2020-04-01  quarta-feira  02:50:00  MT  163.0  667,6
# 15367  277910.0   2020-04-01  quarta-feira  03:00:00  RS  386.0    397
# ...         ...          ...           ...       ...  ..    ...    ...
# 63314  345207.0   2020-04-07   terça-feira  17:51:00  MS  163.0    490
# 63349  346135.0   2020-04-24   sexta-feira  17:52:00  CE  222.0      4
# 63387  348075.0   2020-04-02  quinta-feira  23:00:00  PR  153.0    111
# 63488  357046.0   2020-04-08  quarta-feira  11:50:00  BA  116.0   16,8
# 63539  364377.0   2020-04-05       domingo  20:30:00  BA  116.0      9
#
#                    municipio  \
# 15363                  SERRA
# 15364  SAO JOSE DO RIO PRETO
# ...

# %% [markdown]
# Houve redução do número de acidentes no mês Abril de 2020.

# %%
amai2018 = dtran2018[dtran2018['Mes']==5]
amai2018
# Out:
#              id data_inversa     dia_semana   horario  uf     br     km  \
# 24709  131287.0   2018-05-01    terça-feira  00:45:00  SP  381.0   58,3
# 24711  131290.0   2018-05-01    terça-feira  01:20:00  RS  290.0  142,4
# 24712  131291.0   2018-05-01    terça-feira  01:25:00  SP  116.0    516
# 24713  131292.0   2018-05-01    terça-feira  01:27:00  SC  101.0    207
# 24714  131294.0   2018-05-01    terça-feira  00:55:00  MG   50.0  171,3
# ...         ...          ...            ...       ...  ..    ...    ...
# 69244  238649.0   2018-05-28  segunda-feira  12:30:00  BA  116.0    229
# 69246  239118.0   2018-05-29    terça-feira  18:00:00  PA  222.0    235
# 69247  239392.0   2018-05-23   quarta-feira  17:05:00  PB  230.0     35
# 69249  239399.0   2018-05-03   quinta-feira  17:50:00  GO   40.0   12,8
# 69280  249146.0   2018-05-21  segunda-feira  18:10:00  RJ  116.0    141
#
#                municipio                                     causa_acidente  \
# ...

# %%
amai2019 = dtran2019[dtran2019['Mes']==5]
amai2019
# Out:
#              id data_inversa     dia_semana   horario  uf     br     km  \
# 20657  206551.0   2019-05-01   quarta-feira  00:05:00  SC  282.0  340,1
# 20660  206554.0   2019-05-01   quarta-feira  01:35:00  SP  116.0   44,3
# 20661  206555.0   2019-05-01   quarta-feira  01:00:00  MG   40.0    614
# 20662  206556.0   2019-05-01   quarta-feira  02:30:00  RN  304.0  147,3
# 20663  206557.0   2019-05-01   quarta-feira  01:30:00  SP  116.0   44,3
# ...         ...          ...            ...       ...  ..    ...    ...
# 67222  260301.0   2019-05-29   quarta-feira  16:30:00  RS  158.0  325,3
# 67228  260517.0   2019-05-13  segunda-feira  08:20:00  BA  116.0  418,7
# 67276  261554.0   2019-05-31    sexta-feira  16:30:00  ES  101.0    254
# 67285  261658.0   2019-05-04         sábado  03:40:00  PI  343.0    4,2
# 67359  264064.0   2019-05-27  segunda-feira  23:00:00  BA  116.0    594
#
#               municipio                                     causa_acidente  \
# ...

# %%
amai2020 = dtran2020[dtran2020['Mes']==5]
amai2020
# Out:
#              id data_inversa   dia_semana   horario  uf     br     km  \
# 19175  282244.0   2020-05-01  sexta-feira  00:00:00  PA  230.0  630,5
# 19176  282245.0   2020-05-01  sexta-feira  01:05:00  RJ  101.0    333
# 19178  282247.0   2020-05-01  sexta-feira  02:00:00  PB  101.0     96
# 19179  282248.0   2020-05-01  sexta-feira  01:08:00  RJ    NaN    NaN
# 19180  282249.0   2020-05-01  sexta-feira  02:30:00  MG  381.0  817,8
# ...         ...          ...          ...       ...  ..    ...    ...
# 63452  353348.0   2020-05-17      domingo  23:15:00  PR  277.0    3,3
# 63520  361339.0   2020-05-16       sábado  20:25:00  RN  304.0    306
# 63521  361417.0   2020-05-26  terça-feira  05:50:00  BA  242.0    807
# 63537  364317.0   2020-05-15  sexta-feira  20:30:00  PA  230.0    114
# 63538  364322.0   2020-05-09       sábado  00:15:00  GO   40.0     96
#
#                    municipio  \
# 19175               ALTAMIRA
# 19176         RIO DE JANEIRO
# 19178               ALHANDRA
# ...

# %% [markdown]
# Houve redução do número de acidentes no mês Maio de 2020, porém não foi uma redução tão significativa se comparado ao ano de 2018.

# %%
ajun2018 = dtran2018[dtran2018['Mes']==6]
ajun2018
# Out:
#              id data_inversa     dia_semana   horario  uf     br     km  \
# 29362  137109.0   2018-06-01    sexta-feira  00:15:00  PR  277.0  723,9
# 29363  137110.0   2018-06-01    sexta-feira  00:15:00  SP  116.0  269,9
# 29364  137111.0   2018-06-01    sexta-feira  00:40:00  MG  381.0    863
# 29366  137113.0   2018-06-01    sexta-feira  00:55:00  SC  101.0  277,4
# 29367  137114.0   2018-06-01    sexta-feira  01:45:00  PA  155.0    260
# ...         ...          ...            ...       ...  ..    ...    ...
# 69221  234111.0   2018-06-25  segunda-feira  19:00:00  ES  101.0    292
# 69224  234895.0   2018-06-17        domingo  02:00:00  PR  476.0    124
# 69232  236296.0   2018-06-20   quarta-feira  06:15:00  RN  427.0  102,4
# 69241  237931.0   2018-06-23         sábado  13:00:00  PR  376.0    180
# 69252  240259.0   2018-06-23         sábado  03:50:00  PE  316.0   33,2
#
#                  municipio                                     causa_acidente  \
# ...

# %%
ajun2019 = dtran2019[dtran2019['Mes']==6]
ajun2019
# Out:
#              id data_inversa     dia_semana   horario  uf     br     km  \
# 26076  212833.0   2019-06-01         sábado  00:15:00  PE  232.0   57,3
# 26080  212837.0   2019-06-01         sábado  00:35:00  MG  116.0  317,2
# 26084  212841.0   2019-06-01         sábado  00:50:00  PR  277.0  660,1
# 26085  212844.0   2019-06-01         sábado  01:45:00  MT   70.0      4
# 26088  212847.0   2019-06-01         sábado  02:20:00  GO   40.0    1,9
# ...         ...          ...            ...       ...  ..    ...    ...
# 67223  260313.0   2019-06-08         sábado  18:50:00  SP  116.0    229
# 67268  261368.0   2019-06-22         sábado  18:40:00  BA  110.0    294
# 67291  261729.0   2019-06-15         sábado  10:30:00  RS  448.0     22
# 67336  263316.0   2019-06-03  segunda-feira  19:10:00  PR  376.0    1,2
# 67443  266434.0   2019-06-03  segunda-feira  19:00:00  CE  222.0    1,4
#
#                   municipio                      causa_acidente  \
# ...

# %%
ajun2020 = dtran2020[dtran2020['Mes']==6]
ajun2020
# Out:
#              id data_inversa     dia_semana   horario  uf     br     km  \
# 23776  287499.0   2020-06-01  segunda-feira  00:20:00  RJ  101.0  313,2
# 23781  287504.0   2020-06-01  segunda-feira  00:25:00  RJ  101.0     62
# 23782  287505.0   2020-06-01  segunda-feira  00:45:00  CE  116.0  503,7
# 23785  287508.0   2020-06-01  segunda-feira  00:30:00  GO   20.0  143,1
# 23787  287512.0   2020-06-01  segunda-feira  02:35:00  PE  101.0   47,9
# ...         ...          ...            ...       ...  ..    ...    ...
# 63461  354393.0   2020-06-10   quarta-feira  16:20:00  PI  316.0     85
# 63502  359280.0   2020-06-24   quarta-feira  14:00:00  SC  101.0     58
# 63507  359955.0   2020-06-17   quarta-feira  22:00:00  SC  101.0    134
# 63512  360419.0   2020-06-22  segunda-feira  20:30:00  BA  101.0  185,8
# 63527  362764.0   2020-06-14        domingo  16:50:00  GO  153.0  644,8
#
#                     municipio  \
# 23776             SAO GONCALO
# 23781   CAMPOS DOS GOYTACAZES
# ...

# %% [markdown]
# Houve redução do número de acidentes no mês Junho de 2020.

# %%
ajul2018 = dtran2018[dtran2018['Mes']==7]
ajul2018
# Out:
#              id data_inversa     dia_semana   horario  uf     br     km  \
# 34897  143720.0   2018-07-01        domingo  00:20:00  RS  290.0     90
# 34905  143728.0   2018-07-01        domingo  00:30:00  PA  316.0     66
# 34909  143732.0   2018-07-01        domingo  00:15:00  RJ  116.0  164,8
# 34910  143733.0   2018-07-01        domingo  01:30:00  BA  116.0    813
# 34912  143735.0   2018-07-01        domingo  02:50:00  SC  101.0     84
# ...         ...          ...            ...       ...  ..    ...    ...
# 69165  222422.0   2018-07-17    terça-feira  18:00:00  RJ  493.0      5
# 69226  235045.0   2018-07-10    terça-feira  08:50:00  CE   20.0    410
# 69227  235057.0   2018-07-09  segunda-feira  15:55:00  CE  222.0   46,5
# 69268  243093.0   2018-07-08        domingo  07:40:00  PI  407.0    480
# 69286  250339.0   2018-07-04   quarta-feira  11:35:00  PB  101.0   84,3
#
#                      municipio                causa_acidente  \
# ...

# %%
ajul2019 = dtran2019[dtran2019['Mes']==7]
ajul2019
# Out:
#              id data_inversa     dia_semana   horario  uf     br     km  \
# 31585  219131.0   2019-07-01  segunda-feira  00:20:00  BA  324.0    512
# 31586  219132.0   2019-07-01  segunda-feira  00:00:00  SP  381.0     82
# 31588  219134.0   2019-07-01  segunda-feira  00:40:00  MG  153.0     58
# 31590  219136.0   2019-07-01  segunda-feira  01:20:00  SP  116.0  229,9
# 31591  219137.0   2019-07-01  segunda-feira  00:10:00  SC  470.0    204
# ...         ...          ...            ...       ...  ..    ...    ...
# 67342  263364.0   2019-07-31   quarta-feira  10:30:00  MS   60.0     65
# 67374  264440.0   2019-07-24   quarta-feira  06:30:00  MG  381.0  685,7
# 67389  264789.0   2019-07-04   quinta-feira  19:00:00  PR  116.0    128
# 67430  265979.0   2019-07-02    terça-feira  07:40:00  ES  262.0   92,5
# 67444  266573.0   2019-07-13         sábado  19:35:00  PR  373.0    425
#
#                    municipio  \
# 31585       FEIRA DE SANTANA
# 31586              SAO PAULO
# ...

# %%
ajul2020 = dtran2020[dtran2020['Mes']==7]
ajul2020
# Out:
#              id data_inversa    dia_semana   horario  uf     br     km  \
# 28477  292861.0   2020-07-01  quarta-feira  00:41:00  MG  381.0    780
# 28478  292862.0   2020-07-01  quarta-feira  00:10:00  PE  101.0   52,6
# 28479  292863.0   2020-07-01  quarta-feira  01:25:00  SC  470.0    135
# 28480  292864.0   2020-07-01  quarta-feira  04:05:00  SP  116.0  132,9
# 28481  292865.0   2020-07-01  quarta-feira  01:40:00  AC  364.0  123,2
# ...         ...          ...           ...       ...  ..    ...    ...
# 63335  345631.0   2020-07-19       domingo  06:10:00  PR  116.0      7
# 63427  350617.0   2020-07-30  quinta-feira  19:00:00  MG  381.0  504,4
# 63489  357050.0   2020-07-17   sexta-feira  12:30:00  BA  116.0   15,5
# 63523  361621.0   2020-07-21   terça-feira  18:30:00  PE  316.0  366,3
# 63530  363250.0   2020-07-29  quarta-feira  16:00:00  BA  324.0    622
#
#                   municipio                            causa_acidente  \
# ...

# %% [markdown]
# Houve redução do número de acidentes no mês Julho de 2020.

# %%
aago2018 = dtran2018[dtran2018['Mes']==8]
aago2018
# Out:
#              id data_inversa     dia_semana   horario  uf     br     km  \
# 40417  150163.0   2018-08-01   quarta-feira  00:30:00  ES  101.0  245,9
# 40422  150169.0   2018-08-01   quarta-feira  00:45:00  MG  365.0    464
# 40426  150173.0   2018-08-01   quarta-feira  02:30:00  PB  101.0   73,9
# 40428  150176.0   2018-08-01   quarta-feira  03:30:00  SP  116.0    499
# 40430  150178.0   2018-08-01   quarta-feira  05:10:00  SC  282.0    3,9
# ...         ...          ...            ...       ...  ..    ...    ...
# 69230  235937.0   2018-08-20  segunda-feira  09:30:00  RS  386.0  305,1
# 69233  236393.0   2018-08-02   quinta-feira  18:30:00  RJ   40.0    112
# 69250  240084.0   2018-08-13  segunda-feira  07:10:00  PE  428.0  178,2
# 69254  241394.0   2018-08-02   quinta-feira  18:10:00  PI  343.0     10
# 69276  246777.0   2018-08-07    terça-feira  22:23:00  MG   40.0  550,1
#
#              municipio                                     causa_acidente  \
# ...

# %%
aago2019 = dtran2019[dtran2019['Mes']==8]
aago2019
# Out:
#              id data_inversa    dia_semana   horario  uf     br     km  \
# 37398  225875.0   2019-08-01  quinta-feira  00:28:00  SC  101.0  201,9
# 37400  225877.0   2019-08-01  quinta-feira  01:00:00  ES  101.0  435,9
# 37401  225878.0   2019-08-01  quinta-feira  01:30:00  RJ  116.0    172
# 37402  225879.0   2019-08-01  quinta-feira  02:10:00  PR  376.0    596
# 37403  225880.0   2019-08-01  quinta-feira  01:40:00  MT  163.0    816
# ...         ...          ...           ...       ...  ..    ...    ...
# 65865  258491.0   2019-08-24        sábado  18:00:00  PR  467.0    106
# 67250  260794.0   2019-08-25       domingo  04:35:00  MG  262.0  711,2
# 67354  263981.0   2019-08-03        sábado  16:20:00  BA  418.0     83
# 67358  264061.0   2019-08-24        sábado  21:00:00  CE  116.0  103,2
# 67372  264389.0   2019-08-24        sábado  19:00:00  BA  324.0    550
#
#                 municipio                                     causa_acidente  \
# ...

# %%
aago2020 = dtran2020[dtran2020['Mes']==8]
aago2020
# Out:
#              id data_inversa    dia_semana   horario  uf     br     km  \
# 33643  298669.0   2020-08-01        sábado  01:40:00  PR  376.0  198,6
# 33645  298672.0   2020-08-01        sábado  00:20:00  SP  116.0  116,2
# 33646  298673.0   2020-08-01        sábado  01:35:00  DF   20.0      3
# 33647  298674.0   2020-08-01        sábado  01:50:00  PR  476.0    181
# 33648  298675.0   2020-08-01        sábado  01:40:00  PR  369.0  473,8
# ...         ...          ...           ...       ...  ..    ...    ...
# 63482  356392.0   2020-08-22        sábado  21:30:00  PA  230.0  121,7
# 63484  356882.0   2020-08-02       domingo  18:00:00  PR  476.0  117,5
# 63509  360062.0   2020-08-27  quinta-feira  16:10:00  BA  324.0    307
# 63519  361197.0   2020-08-20  quinta-feira  16:40:00  BA  101.0    288
# 63531  363428.0   2020-08-22        sábado  15:30:00  RO  364.0    429
#
#       municipio                                     causa_acidente  \
# ...

# %% [markdown]
# Houve redução do número de acidentes no mês Agosto de 2020 se comparado ao ano de 2019, porém comparando com o ano de 2018 houve aumento.

# %%
aset2018 = dtran2018[dtran2018['Mes']==9]
aset2018
# Out:
#              id data_inversa    dia_semana   horario  uf     br    km  \
# 45941  156470.0   2018-09-01        sábado  01:30:00  DF   20.0     9
# 45945  156474.0   2018-09-01        sábado  01:35:00  DF   80.0    19
# 45946  156475.0   2018-09-01        sábado  02:00:00  SP  116.0   414
# 45947  156476.0   2018-09-01        sábado  01:25:00  BA  330.0   805
# 45948  156477.0   2018-09-01        sábado  03:10:00  DF   80.0  13,7
# ...         ...          ...           ...       ...  ..    ...   ...
# 69253  241392.0   2018-09-05  quarta-feira  07:40:00  MG   40.0   509
# 69262  242390.0   2018-09-08        sábado  04:00:00  BA  110.0   207
# 69271  245287.0   2018-09-20  quinta-feira  22:00:00  MG  364.0   5,2
# 69275  246462.0   2018-09-02       domingo  22:20:00  PR  476.0   128
# 69282  249214.0   2018-09-11   terça-feira  12:20:00  MG   40.0   520
#
#                 municipio               causa_acidente  \
# 45941            BRASILIA      Velocidade Incompatível
# ...

# %%
aset2019 = dtran2019[dtran2019['Mes']==9]
aset2019
# Out:
#              id data_inversa     dia_semana   horario  uf     br     km  \
# 43103  232367.0   2019-09-01        domingo  00:10:00  SC  101.0    242
# 43104  232368.0   2019-09-01        domingo  00:15:00  ES  101.0    131
# 43106  232370.0   2019-09-01        domingo  00:30:00  RJ  393.0    218
# 43107  232371.0   2019-09-01        domingo  00:30:00  PR  373.0    179
# 43109  232374.0   2019-09-01        domingo  00:25:00  RS  101.0   51,7
# ...         ...          ...            ...       ...  ..    ...    ...
# 67373  264390.0   2019-09-20    sexta-feira  09:50:00  PR  163.0    278
# 67380  264581.0   2019-09-21         sábado  23:00:00  SP  381.0     34
# 67390  264837.0   2019-09-26   quinta-feira  06:40:00  BA  116.0    596
# 67416  265662.0   2019-09-18   quarta-feira  15:16:00  MG  381.0  932,7
# 67427  265857.0   2019-09-09  segunda-feira  15:50:00  AM  319.0    820
#
#             municipio                                     causa_acidente  \
# ...

# %%
aset2020 = dtran2020[dtran2020['Mes']==9]
aset2020
# Out:
#              id data_inversa    dia_semana   horario  uf     br     km  \
# 39269  304924.0   2020-09-01   terça-feira  01:30:00  MG  381.0  534,7
# 39270  304925.0   2020-09-01   terça-feira  01:45:00  SC  101.0   89,3
# 39271  304926.0   2020-09-01   terça-feira  01:20:00  MG  381.0  223,2
# 39272  304927.0   2020-09-01   terça-feira  00:50:00  MS  163.0  570,7
# 39273  304928.0   2020-09-01   terça-feira  03:00:00  MG  381.0    429
# ...         ...          ...           ...       ...  ..    ...    ...
# 63505  359858.0   2020-09-11   sexta-feira  12:50:00  RJ  393.0    298
# 63526  361811.0   2020-09-18   sexta-feira  17:35:00  SC  282.0   16,4
# 63532  363433.0   2020-09-23  quarta-feira  20:30:00  RO  364.0    702
# 63544  364810.0   2020-09-12        sábado  23:50:00  BA  116.0   11,5
# 63546  364835.0   2020-09-20       domingo  23:00:00  BA  116.0      8
#
#                   municipio  \
# 39269            ITATIAIUCU
# 39270           BARRA VELHA
# ...

# %% [markdown]
# Houve redução do número de acidentes no mês Setembro de 2020 se comparado ao ano de 2019, porém comparando com o ano de 2018 houve aumento.

# %%
aout2018 = dtran2018[dtran2018['Mes']==10]
aout2018
# Out:
#              id data_inversa     dia_semana   horario  uf     br     km  \
# 51406  162667.0   2018-10-01  segunda-feira  00:04:00  RN  101.0  110,4
# 51407  162668.0   2018-10-01  segunda-feira  00:20:00  RN  304.0   54,8
# 51408  162669.0   2018-10-01  segunda-feira  00:05:00  MG  381.0    821
# 51410  162671.0   2018-10-01  segunda-feira  00:12:00  MG   50.0  178,8
# 51411  162672.0   2018-10-01  segunda-feira  01:10:00  SP  153.0  275,6
# ...         ...          ...            ...       ...  ..    ...    ...
# 69214  232733.0   2018-10-16    terça-feira  06:29:00  DF   20.0     16
# 69220  233747.0   2018-10-18   quinta-feira  19:20:00  SE  101.0     35
# 69234  236450.0   2018-10-26    sexta-feira  15:00:00  MG  116.0  277,2
# 69266  242705.0   2018-10-09    terça-feira  06:30:00  BA  324.0    607
# 69294  253078.0   2018-10-01  segunda-feira  04:31:00  GO   40.0      9
#
#            municipio                      causa_acidente  \
# ...

# %%
aout2019 = dtran2019[dtran2019['Mes']==10]
aout2019
# Out:
#              id data_inversa     dia_semana   horario  uf     br     km  \
# 49015  239301.0   2019-10-01    terça-feira  00:10:00  PR  369.0    147
# 49017  239304.0   2019-10-01    terça-feira  00:40:00  PR  277.0  654,6
# 49018  239305.0   2019-10-01    terça-feira  01:20:00  DF   20.0     43
# 49019  239306.0   2019-10-01    terça-feira  02:00:00  GO  452.0   40,5
# 49022  239309.0   2019-10-01    terça-feira  02:30:00  RJ  101.0  304,2
# ...         ...          ...            ...       ...  ..    ...    ...
# 67421  265761.0   2019-10-09   quarta-feira  13:30:00  MA  135.0     22
# 67425  265822.0   2019-10-06        domingo  15:00:00  SC  101.0    334
# 67426  265836.0   2019-10-06        domingo  03:30:00  RJ  101.0    296
# 67441  266255.0   2019-10-07  segunda-feira  09:10:00  ES  101.0  270,5
# 67445  266627.0   2019-10-22    terça-feira  20:20:00  BA  324.0    608
#
#                    municipio  \
# 49015               LONDRINA
# 49017             MATELANDIA
# ...

# %%
aout2020 = dtran2020[dtran2020['Mes']==10]
aout2020
# Out:
#              id data_inversa     dia_semana   horario  uf     br     km  \
# 45015  311345.0   2020-10-01   quinta-feira  00:20:00  RJ  493.0     18
# 45019  311349.0   2020-10-01   quinta-feira  03:40:00  PE  232.0    252
# 45020  311350.0   2020-10-01   quinta-feira  01:50:00  RS  386.0  279,4
# 45021  311352.0   2020-10-01   quinta-feira  04:25:00  SC  116.0    1,8
# 45022  311353.0   2020-10-01   quinta-feira  01:30:00  CE  116.0   45,2
# ...         ...          ...            ...       ...  ..    ...    ...
# 63504  359854.0   2020-10-03         sábado  20:10:00  PR  476.0    119
# 63514  360488.0   2020-10-29   quinta-feira  06:45:00  ES  101.0    293
# 63524  361638.0   2020-10-05  segunda-feira  13:30:00  MG  267.0   79,6
# 63545  364817.0   2020-10-30    sexta-feira  10:30:00  BA  116.0   14,3
# 63547  364903.0   2020-10-31         sábado  02:10:00  BA  116.0      3
#
#                   municipio  \
# 45015                  MAGE
# 45019             ARCOVERDE
# ...

# %% [markdown]
# Houve aumento do número de acidentes no mês Setembro de 2020, mesmo com a pandemia.

# %%
anov2018 = dtran2018[dtran2018['Mes']==11]
anov2018
# Out:
#              id data_inversa     dia_semana   horario  uf     br     km  \
# 56831  168856.0   2018-11-01   quinta-feira  00:01:00  RJ  116.0  277,1
# 56832  168857.0   2018-11-01   quinta-feira  00:02:00  SP  116.0   62,2
# 56833  168858.0   2018-11-01   quinta-feira  00:15:00  MG   40.0   42,3
# 56837  168863.0   2018-11-01   quinta-feira  02:15:00  RJ  493.0     17
# 56838  168864.0   2018-11-01   quinta-feira  02:30:00  MG  267.0  201,3
# ...         ...          ...            ...       ...  ..    ...    ...
# 69281  249191.0   2018-11-24         sábado  19:50:00  RN  226.0  244,9
# 69285  249672.0   2018-11-12  segunda-feira  18:29:00  BA  101.0    367
# 69289  251818.0   2018-11-29   quinta-feira  16:30:00  AP  210.0     54
# 69292  252801.0   2018-11-15   quinta-feira  10:48:00  SP  116.0    529
# 69293  253040.0   2018-11-23    sexta-feira  19:30:00  RS  472.0  573,5
#
#                  municipio                                     causa_acidente  \
# ...

# %%
anov2019 = dtran2019[dtran2019['Mes']==11]
anov2019
# Out:
#              id data_inversa     dia_semana   horario  uf     br     km  \
# 54971  246404.0   2019-11-01    sexta-feira  00:20:00  RS  293.0   15,5
# 54973  246407.0   2019-11-01    sexta-feira  00:30:00  TO  153.0  497,1
# 54974  246408.0   2019-11-01    sexta-feira  01:40:00  CE  116.0     42
# 54975  246409.0   2019-11-01    sexta-feira  01:50:00  RJ  116.0    272
# 54976  246410.0   2019-11-01    sexta-feira  02:05:00  GO   50.0   97,4
# ...         ...          ...            ...       ...  ..    ...    ...
# 67409  265494.0   2019-11-24        domingo  16:20:00  BA  101.0  551,4
# 67424  265798.0   2019-11-16         sábado  19:00:00  BA  101.0    524
# 67431  265991.0   2019-11-03        domingo  19:50:00  AL  316.0  245,9
# 67434  266131.0   2019-11-29    sexta-feira  17:50:00  PE  101.0   74,3
# 67442  266406.0   2019-11-25  segunda-feira  07:20:00  PR  116.0    125
#
#                   municipio  \
# 54971         CAPAO DO LEAO
# 54973  PARAISO DO TOCANTINS
# ...

# %%
anov2020 = dtran2020[dtran2020['Mes']==11]
anov2020
# Out:
#              id data_inversa    dia_semana   horario  uf     br     km  \
# 51100  318405.0   2020-11-01       domingo  01:01:00  MG  381.0  390,9
# 51103  318409.0   2020-11-01       domingo  01:05:00  GO   60.0  169,2
# 51108  318414.0   2020-11-01       domingo  01:02:00  SC  470.0   58,9
# 51109  318415.0   2020-11-01       domingo  01:00:00  GO   70.0    3,6
# 51112  318419.0   2020-11-01       domingo  01:40:00  GO   60.0  102,8
# ...         ...          ...           ...       ...  ..    ...    ...
# 63460  354182.0   2020-11-03   terça-feira  20:00:00  MT  364.0    181
# 63481  356338.0   2020-11-01       domingo  12:00:00  ES  259.0     44
# 63506  359881.0   2020-11-12  quinta-feira  12:34:00  MG   50.0  183,7
# 63515  360662.0   2020-11-18  quarta-feira  22:30:00  AL  101.0    125
# 63528  362882.0   2020-11-25  quarta-feira  10:22:00  SP  153.0     76
#
#                    municipio  \
# 51100        BARAO DE COCAIS
# 51103        ABADIA DE GOIAS
# ...

# %% [markdown]
# Houve redução do número de acidentes no mês Novembro de 2020 se comparado ao ano de 2019, porém comparando com o ano de 2018 houve aumento.

# %%
adez2018 = dtran2018[dtran2018['Mes']==12]
adez2018
# Out:
#              id data_inversa     dia_semana   horario  uf     br     km  \
# 62220  175077.0   2018-12-01         sábado  00:00:00  RJ  101.0    308
# 62224  175082.0   2018-12-01         sábado  00:20:00  ES  101.0  269,6
# 62228  175086.0   2018-12-01         sábado  01:00:00  SP  116.0    298
# 62229  175087.0   2018-12-01         sábado  00:10:00  MG  251.0    227
# 62230  175088.0   2018-12-01         sábado  01:45:00  MG  381.0    503
# ...         ...          ...            ...       ...  ..    ...    ...
# 69269  244788.0   2018-12-19   quarta-feira  15:15:00  RS  285.0    269
# 69287  250959.0   2018-12-27   quinta-feira  12:50:00  RJ   40.0    103
# 69288  251169.0   2018-12-23        domingo  17:55:00  AL  101.0   73,8
# 69290  252256.0   2018-12-24  segunda-feira  09:15:00  PI  343.0  263,1
# 69291  252652.0   2018-12-12   quarta-feira  07:00:00  BA  101.0    321
#
#                        municipio  \
# 62220                SAO GONCALO
# ...

# %%
adez2019 = dtran2019[dtran2019['Mes']==12]
adez2019
# Out:
#              id data_inversa     dia_semana   horario  uf     br     km  \
# 60823  252997.0   2019-12-01        domingo  00:05:00  RN  101.0     96
# 60824  252998.0   2019-12-01        domingo  01:00:00  CE  222.0    205
# 60825  252999.0   2019-12-01        domingo  01:00:00  SC  280.0    6,5
# 60826  253000.0   2019-12-01        domingo  00:51:00  SP  116.0   39,6
# 60830  253004.0   2019-12-01        domingo  01:00:00  RJ  116.0    177
# ...         ...          ...            ...       ...  ..    ...    ...
# 67428  265911.0   2019-12-20    sexta-feira  12:45:00  SC  282.0      3
# 67429  265977.0   2019-12-25   quarta-feira  06:45:00  RS  116.0    236
# 67436  266137.0   2019-12-23  segunda-feira  20:10:00  SE  235.0     57
# 67437  266146.0   2019-12-25   quarta-feira  10:00:00  SC  282.0  579,8
# 67440  266162.0   2019-12-24    terça-feira  16:10:00  MG  267.0    231
#
#                   municipio  \
# 60823                 NATAL
# 60824             FORQUILHA
# ...

# %%
adez2020 = dtran2020[dtran2020['Mes']==12]
adez2020
# Out:
#              id data_inversa    dia_semana   horario  uf     br     km  \
# 56841  324907.0   2020-12-01   terça-feira  00:20:00  RS  290.0    104
# 56842  324908.0   2020-12-01   terça-feira  00:30:00  RN  304.0     34
# 56844  324910.0   2020-12-01   terça-feira  01:20:00  AL  101.0  134,7
# 56845  324911.0   2020-12-01   terça-feira  01:00:00  PR  277.0   41,5
# 56846  324912.0   2020-12-01   terça-feira  01:20:00  SC  101.0    216
# ...         ...          ...           ...       ...  ..    ...    ...
# 63522  361606.0   2020-12-08   terça-feira  21:10:00  PR  376.0    651
# 63525  361806.0   2020-12-13       domingo  17:50:00  PR  153.0    347
# 63540  364457.0   2020-12-17  quinta-feira  13:20:00  RJ  101.0    308
# 63541  364489.0   2020-12-04   sexta-feira  16:40:00  SE  101.0   53,6
# 63542  364608.0   2020-12-18   sexta-feira  15:45:00  MT  364.0   25,3
#
#                    municipio                      causa_acidente  \
# ...

# %% [markdown]
# Houve redução do número de acidentes no mês Dezembro de 2020.

# %% [markdown]
# É possível concluir que no geral na maioria dos meses houve redução da incidência de acidentes nas rodovias federais como consequência da pandemia.
